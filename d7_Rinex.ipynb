# %% [markdown]
# <a href="https://colab.research.google.com/github/AbdulKareem156/kareem2-/blob/main/d7_Rinex.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#pandas -tabeled data(organised data)
#seris-column(one D)
a = {'cars':['BMW','RR','Ford'],'sales':[6,3,7]}
a
# Out:
# {'cars': ['BMW', 'RR', 'Ford'], 'sales': [6, 3, 7]}

# %%
type(a)
# Out:
# dict

# %%
import pandas as pd
#dataframe-is tabled data and panda is used to create dataframe
df=pd.DataFrame(a,index=['s','h','f'])
df
# Out:
#    cars  sales
# s   BMW      6
# h    RR      3
# f  Ford      7

# %%
b=[1,7,2,6]
df1=pd.Series(b)
df1
# Out:
# 0    1
# 1    7
# 2    2
# 3    6
# dtype: int64

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df1)
# Out:
# pandas.core.series.Series

# %%
c=[1,7,2,6]
df2=pd.Series(c,index=['x','e','r','q'])
df2
# Out:
# x    1
# e    7
# r    2
# q    6
# dtype: int64

# %%
sports1=pd.Series([1,2,3,4],index=['cricket','football','hockey','golf'])
sports1
# Out:
# cricket     1
# football    2
# hockey      3
# golf        4
# dtype: int64

# %%
sports2=pd.Series([1,2,5,4],index=['cricket','Basketball','BaseBall','golf'])
sports2
# Out:
# cricket       1
# Basketball    2
# BaseBall      5
# golf          4
# dtype: int64

# %%
s=sports1+sports2
s
# Out:
# BaseBall      NaN
# Basketball    NaN
# cricket       2.0
# football      NaN
# golf          8.0
# hockey        NaN
# dtype: float64

# %%
#NaN-Not a Number(Null Value)

# %%
import numpy as np
df=pd.DataFrame({'cricket':[1,2,np.nan,6,0,2,np.nan],'BaseBall':[5,6,np.nan,3,np.nan,2,7],'Tenneis':[1,2,3,4,5,6,7]})
df
# Out:
#    cricket  BaseBall  Tenneis
# 0      1.0       5.0        1
# 1      2.0       6.0        2
# 2      NaN       NaN        3
# 3      6.0       3.0        4
# 4      0.0       NaN        5
# 5      2.0       2.0        6
# 6      NaN       7.0        7

# %%
#Remove (nan) values
df.dropna()
# Out:
#    cricket  BaseBall  Tenneis
# 0      1.0       5.0        1
# 1      2.0       6.0        2
# 3      6.0       3.0        4
# 5      2.0       2.0        6

# %%
#Replacing nan values with zeroes
df.fillna(value=0)
# Out:
#    cricket  BaseBall  Tenneis
# 0      1.0       5.0        1
# 1      2.0       6.0        2
# 2      0.0       0.0        3
# 3      6.0       3.0        4
# 4      0.0       0.0        5
# 5      2.0       2.0        6
# 6      0.0       7.0        7

# %%
#Exploratory Data Analysis(EDA)
import pandas as pd
df=pd.read_csv('https://storage.googleapis.com/kagglesdsdata/datasets/9590/13660/fruit_data_with_colors.txt?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20220119%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20220119T152525Z&X-Goog-Expires=259199&X-Goog-SignedHeaders=host&X-Goog-Signature=...',sep ='\t')
df
# Out:
#     fruit_label fruit_name     fruit_subtype  mass  width  height  color_score
# 0             1      apple      granny_smith   192    8.4     7.3         0.55
# 1             1      apple      granny_smith   180    8.0     6.8         0.59
# 2             1      apple      granny_smith   176    7.4     7.2         0.60
# 3             2   mandarin          mandarin    86    6.2     4.7         0.80
# 4             2   mandarin          mandarin    84    6.0     4.6         0.79
# 5             2   mandarin          mandarin    80    5.8     4.3         0.77
# 6             2   mandarin          mandarin    80    5.9     4.3         0.81
# 7             2   mandarin          mandarin    76    5.8     4.0         0.81
# 8             1      apple          braeburn   178    7.1     7.8         0.92
# 9             1      apple          braeburn   172    7.4     7.0         0.89
# 10            1      apple          braeburn   166    6.9     7.3         0.93
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59 entries, 0 to 58
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   fruit_label    59 non-null     int64
#  1   fruit_name     59 non-null     object
#  2   fruit_subtype  59 non-null     object
#  3   mass           59 non-null     int64
#  4   width          59 non-null     float64
#  5   height         59 non-null     float64
#  6   color_score    59 non-null     float64
# dtypes: float64(3), int64(2), object(2)
# memory usage: 3.4+ KB

# %%
df.shape#(R,C)
# Out:
# (59, 7)

# %%
df.size#total numder of data frame
# Out:
# 413

# %%
df.head(5)
# Out:
#    fruit_label fruit_name fruit_subtype  mass  width  height  color_score
# 0            1      apple  granny_smith   192    8.4     7.3         0.55
# 1            1      apple  granny_smith   180    8.0     6.8         0.59
# 2            1      apple  granny_smith   176    7.4     7.2         0.60
# 3            2   mandarin      mandarin    86    6.2     4.7         0.80
# 4            2   mandarin      mandarin    84    6.0     4.6         0.79

# %%
df.tail(-53)
# Out:
#     fruit_label fruit_name fruit_subtype  mass  width  height  color_score
# 53            4      lemon       unknown   120    6.0     8.4         0.74
# 54            4      lemon       unknown   116    6.1     8.5         0.71
# 55            4      lemon       unknown   116    6.3     7.7         0.72
# 56            4      lemon       unknown   116    5.9     8.1         0.73
# 57            4      lemon       unknown   152    6.5     8.5         0.72
# 58            4      lemon       unknown   118    6.1     8.1         0.70

# %%
#Slice data from row 23 to row 45
df[40:51]
# Out:
#     fruit_label fruit_name   fruit_subtype  mass  width  height  color_score
# 40            3     orange    turkey_navel   154    7.1     7.5         0.78
# 41            3     orange    turkey_navel   180    7.6     8.2         0.79
# 42            3     orange    turkey_navel   154    7.2     7.2         0.82
# 43            4      lemon  spanish_belsan   194    7.2    10.3         0.70
# 44            4      lemon  spanish_belsan   200    7.3    10.5         0.72
# 45            4      lemon  spanish_belsan   186    7.2     9.2         0.72
# 46            4      lemon  spanish_belsan   216    7.3    10.2         0.71
# 47            4      lemon  spanish_belsan   196    7.3     9.7         0.72
# 48            4      lemon  spanish_belsan   174    7.3    10.1         0.72
# 49            4      lemon         unknown   132    5.8     8.7         0.73
# 50            4      lemon         unknown   130    6.0     8.2         0.71

# %%
#I want to slice row 23 to 45 and col 0,1,2
#.iloc[rows,cols]
df.iloc[23:46,0:4]#df.iloc[23:46,[0,1,2]]
# Out:
#     fruit_label fruit_name     fruit_subtype  mass
# 23            1      apple       cripps_pink   170
# 24            3     orange     spanish_jumbo   342
# 25            3     orange     spanish_jumbo   356
# 26            3     orange     spanish_jumbo   362
# 27            3     orange  selected_seconds   204
# 28            3     orange  selected_seconds   140
# 29            3     orange  selected_seconds   160
# 30            3     orange  selected_seconds   158
# 31            3     orange  selected_seconds   210
# 32            3     orange  selected_seconds   164
# 33            3     orange      turkey_navel   190
# 34            3     orange      turkey_navel   142
# 35            3     orange      turkey_navel   150
# 36            3     orange      turkey_navel   160
# 37            3     orange      turkey_navel   154
# 38            3     orange      turkey_navel   158
# 39            3     orange      turkey_navel   144
# ...

# %%
df.iloc[23:46,[0,1,2]]
# Out:
#     fruit_label fruit_name     fruit_subtype
# 23            1      apple       cripps_pink
# 24            3     orange     spanish_jumbo
# 25            3     orange     spanish_jumbo
# 26            3     orange     spanish_jumbo
# 27            3     orange  selected_seconds
# 28            3     orange  selected_seconds
# 29            3     orange  selected_seconds
# 30            3     orange  selected_seconds
# 31            3     orange  selected_seconds
# 32            3     orange  selected_seconds
# 33            3     orange      turkey_navel
# 34            3     orange      turkey_navel
# 35            3     orange      turkey_navel
# 36            3     orange      turkey_navel
# 37            3     orange      turkey_navel
# 38            3     orange      turkey_navel
# 39            3     orange      turkey_navel
# 40            3     orange      turkey_navel
# 41            3     orange      turkey_navel
# 42            3     orange      turkey_navel
# ...

# %%
fname=df['fruit_name']
fname
# Out:
# 0        apple
# 1        apple
# 2        apple
# 3     mandarin
# 4     mandarin
# 5     mandarin
# 6     mandarin
# 7     mandarin
# 8        apple
# 9        apple
# 10       apple
# 11       apple
# 12       apple
# 13       apple
# 14       apple
# 15       apple
# 16       apple
# 17       apple
# 18       apple
# 19       apple
# 20       apple
# 21       apple
# 22       apple
# 23       apple
# 24      orange
# 25      orange
# 26      orange
# 27      orange
# 28      orange
# 29      orange
# 30      orange
# 31      orange
# 32      orange
# 33      orange
# 34      orange
# 35      orange
# 36      orange
# 37      orange
# 38      orange
# 39      orange
# 40      orange
# 41      orange
# 42      orange
# 43       lemon
# 44       lemon
# 45       lemon
# 46       lemon
# 47       lemon
# 48       lemon
# 49       lemon
# 50       lemon
# 51       lemon
# 52       lemon
# 53       lemon
# 54       lemon
# 55       lemon
# 56       lemon
# 57       lemon
# ...

# %%
#using python I want to fins the unique fruits in data frame
fname=df['fruit_name'].unique()
fname
# Out:
# array(['apple', 'mandarin', 'orange', 'lemon'], dtype=object)

# %%
fsize=df.groupby('fruit_name',sort=False).size()
fsize
# Out:
# fruit_name
# apple       19
# mandarin     5
# orange      19
# lemon       16
# dtype: int64

# %%
import matplotlib.pyplot as plt
plt.bar(fname,fsize,color=['red','blue','green','pink'])
# Out:
# <BarContainer object of 4 artists>
